# %%
# Loading Dataset

import pandas as pd

df = pd.read_csv('/content/raw_dataset.csv')

# %%
#Preview Dataset
df
# Out:
#   First Name Last name         Age   SALARY            STREET Address1  \
# 0       Joel   Padilla  10/28/2019  $92.32            431-6530 Eu, Rd.
# 1      Fritz     Tyler   9/27/2019  $83.91         Ap #377-2267 Ac Av.
# 2       Wing    Phelps   2/18/2019  $17.15   Ap #545-5786 Pulvinar Ave
# 3       Ryan      Ross   5/21/2019  $45.97            634-7858 Id Road
#
#                 STREET Address2                 STREET Address3  \
# 0            364-2264 Augue Rd.  P.O. Box 864, 3882 Orci Street
# 1              979-2228 Vel Ave                     9865 Eu Av.
# 2  Ap #973-5781 Sagittis Avenue                     9959 Ut St.
# 3        907-8824 Fringilla Ave                 318-5271 In Ave
#
#                                   email
# 0                           eu@nibh.com
# 1  est.ac.mattis@malesuadafringilla.net
# 2                     dolor@cubilia.net
# 3     interdum.libero.dui@vitaeerat.com

# %%
#Preview Columns in Dataset
df.columns
# Out:
# Index(['First Name', 'Last name', 'Age', 'SALARY', 'STREET Address1',
#        'STREET Address2', 'STREET Address3', 'email'],
#       dtype='object')

# %%
#Get the Column Names as List
df.columns.tolist()
# Out:
# ['First Name',
#  'Last name',
#  'Age',
#  'SALARY',
#  'STREET Address1',
#  'STREET Address2',
#  'STREET Address3',
#  'email']

# %%
#Convert Column Names to Series/Dataframe
df.columns.to_series()
# Out:
# First Name              First Name
# Last name                Last name
# Age                            Age
# SALARY                      SALARY
# STREET Address1    STREET Address1
# STREET Address2    STREET Address2
# STREET Address3    STREET Address3
# email                        email
# dtype: object

# %%
#Check if Column Names are duplucated
df.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False])

# %%
# Making Columns Name lower Case
df.columns.str.lower()
# Out:
# Index(['first name', 'last name', 'age', 'salary', 'street address1',
#        'street address2', 'street address3', 'email'],
#       dtype='object')

# %%
# Making Columns Name upper Case
df.columns.str.upper()
# Out:
# Index(['FIRST NAME', 'LAST NAME', 'AGE', 'SALARY', 'STREET ADDRESS1',
#        'STREET ADDRESS2', 'STREET ADDRESS3', 'EMAIL'],
#       dtype='object')

# %%
# Making Columns Name Proper/Title Case
df.columns.str.title()
# Out:
# Index(['First Name', 'Last Name', 'Age', 'Salary', 'Street Address1',
#        'Street Address2', 'Street Address3', 'Email'],
#       dtype='object')

# %%
#Replacing Empty Spaces with Underscore
df.columns.str.replace(' ', '_')
# Out:
# Index(['First_Name', 'Last_name', 'Age', 'SALARY', 'STREET_Address1',
#        'STREET_Address2', 'STREET_Address3', 'email'],
#       dtype='object')

# %%
#Renaming Column Names
df.rename(columns={'Age':'Dates_of_Birth'},inplace=True)
df
# Out:
#   First Name Last name Dates_of_Birth   SALARY            STREET Address1  \
# 0       Joel   Padilla     10/28/2019  $92.32            431-6530 Eu, Rd.
# 1      Fritz     Tyler      9/27/2019  $83.91         Ap #377-2267 Ac Av.
# 2       Wing    Phelps      2/18/2019  $17.15   Ap #545-5786 Pulvinar Ave
# 3       Ryan      Ross      5/21/2019  $45.97            634-7858 Id Road
#
#                 STREET Address2                 STREET Address3  \
# 0            364-2264 Augue Rd.  P.O. Box 864, 3882 Orci Street
# 1              979-2228 Vel Ave                     9865 Eu Av.
# 2  Ap #973-5781 Sagittis Avenue                     9959 Ut St.
# 3        907-8824 Fringilla Ave                 318-5271 In Ave
#
#                                   email
# 0                           eu@nibh.com
# 1  est.ac.mattis@malesuadafringilla.net
# 2                     dolor@cubilia.net
# 3     interdum.libero.dui@vitaeerat.com

# %%
#Checking the lenght of Columns
len(df.columns)
# Out:
# 8

# %%
#Renaming Column Names using indexing (e.g Dates_of_Birth column)

df.columns.values[2] = "DOB"
df
# Out:
#   First Name Last name         DOB   SALARY            STREET Address1  \
# 0       Joel   Padilla  10/28/2019  $92.32            431-6530 Eu, Rd.
# 1      Fritz     Tyler   9/27/2019  $83.91         Ap #377-2267 Ac Av.
# 2       Wing    Phelps   2/18/2019  $17.15   Ap #545-5786 Pulvinar Ave
# 3       Ryan      Ross   5/21/2019  $45.97            634-7858 Id Road
#
#                 STREET Address2                 STREET Address3  \
# 0            364-2264 Augue Rd.  P.O. Box 864, 3882 Orci Street
# 1              979-2228 Vel Ave                     9865 Eu Av.
# 2  Ap #973-5781 Sagittis Avenue                     9959 Ut St.
# 3        907-8824 Fringilla Ave                 318-5271 In Ave
#
#                                   email
# 0                           eu@nibh.com
# 1  est.ac.mattis@malesuadafringilla.net
# 2                     dolor@cubilia.net
# 3     interdum.libero.dui@vitaeerat.com

# %%
# Selecting all columns except one
df.columns[df.columns != 'DOB']
# Out:
# Index(['First Name', 'Last name', 'SALARY', 'STREET Address1',
#        'STREET Address2', 'STREET Address3', 'email'],
#       dtype='object')

# %%
# Selecting all columns except one using LOC
df.loc[:,df.columns != 'DOB']
# Out:
#   First Name Last name   SALARY            STREET Address1  \
# 0       Joel   Padilla  $92.32            431-6530 Eu, Rd.
# 1      Fritz     Tyler  $83.91         Ap #377-2267 Ac Av.
# 2       Wing    Phelps  $17.15   Ap #545-5786 Pulvinar Ave
# 3       Ryan      Ross  $45.97            634-7858 Id Road
#
#                 STREET Address2                 STREET Address3  \
# 0            364-2264 Augue Rd.  P.O. Box 864, 3882 Orci Street
# 1              979-2228 Vel Ave                     9865 Eu Av.
# 2  Ap #973-5781 Sagittis Avenue                     9959 Ut St.
# 3        907-8824 Fringilla Ave                 318-5271 In Ave
#
#                                   email
# 0                           eu@nibh.com
# 1  est.ac.mattis@malesuadafringilla.net
# 2                     dolor@cubilia.net
# 3     interdum.libero.dui@vitaeerat.com

# %%
# Viewing only one column in the dataframe using LOC
df.loc[:,df.columns.isin(['DOB'])]
# Out:
#           DOB
# 0  10/28/2019
# 1   9/27/2019
# 2   2/18/2019
# 3   5/21/2019

# %%
# Select Column Names That Begins with a Word or Character using Filter
df.filter(like='STREET')

#Note that this function is case sensitive
# Out:
#              STREET Address1               STREET Address2  \
# 0           431-6530 Eu, Rd.            364-2264 Augue Rd.
# 1        Ap #377-2267 Ac Av.              979-2228 Vel Ave
# 2  Ap #545-5786 Pulvinar Ave  Ap #973-5781 Sagittis Avenue
# 3           634-7858 Id Road        907-8824 Fringilla Ave
#
#                   STREET Address3
# 0  P.O. Box 864, 3882 Orci Street
# 1                     9865 Eu Av.
# 2                     9959 Ut St.
# 3                 318-5271 In Ave

# %%
# Select Column Names That Begins with a Word or Character using loc
df.loc[:,df.columns.str.startswith('STREET')]

#Note that this function is case sensitive
# Out:
#              STREET Address1               STREET Address2  \
# 0           431-6530 Eu, Rd.            364-2264 Augue Rd.
# 1        Ap #377-2267 Ac Av.              979-2228 Vel Ave
# 2  Ap #545-5786 Pulvinar Ave  Ap #973-5781 Sagittis Avenue
# 3           634-7858 Id Road        907-8824 Fringilla Ave
#
#                   STREET Address3
# 0  P.O. Box 864, 3882 Orci Street
# 1                     9865 Eu Av.
# 2                     9959 Ut St.
# 3                 318-5271 In Ave

# %%
# Select Column Names That Ends with a Word or Character using Filter
df.filter(regex='ame$',axis=1)

#Note that this function is case sensitive
# Out:
#   First Name Last name
# 0       Joel   Padilla
# 1      Fritz     Tyler
# 2       Wing    Phelps
# 3       Ryan      Ross

# %%
# Select Column Names That Begins with a Word or Character using loc
df.loc[:,df.columns.str.endswith('ame')]
#Note that this function is case sensitive
# Out:
#   First Name Last name
# 0       Joel   Padilla
# 1      Fritz     Tyler
# 2       Wing    Phelps
# 3       Ryan      Ross

# %%
# Select A group of column Names with indexing

df.columns[[0,1,2]]
# Out:
# Index(['First Name', 'Last name', 'DOB'], dtype='object')

# %%
#Joining Two Columns together
df['Full_Name'] = df['First Name'] + ' ' + df['Last name']

#Viewing the new column
df.loc[:,df.columns.isin(['Full_Name'])].head()
# Out:
#       Full_Name
# 0  Joel Padilla
# 1   Fritz Tyler
# 2   Wing Phelps
# 3     Ryan Ross

# %%
#Dropping multiple column
columns_to_drop = ['First Name', 'Last name']
df.drop(columns=columns_to_drop, inplace=True)
df
# Out:
#           DOB   SALARY            STREET Address1  \
# 0  10/28/2019  $92.32            431-6530 Eu, Rd.
# 1   9/27/2019  $83.91         Ap #377-2267 Ac Av.
# 2   2/18/2019  $17.15   Ap #545-5786 Pulvinar Ave
# 3   5/21/2019  $45.97            634-7858 Id Road
#
#                 STREET Address2                 STREET Address3  \
# 0            364-2264 Augue Rd.  P.O. Box 864, 3882 Orci Street
# 1              979-2228 Vel Ave                     9865 Eu Av.
# 2  Ap #973-5781 Sagittis Avenue                     9959 Ut St.
# 3        907-8824 Fringilla Ave                 318-5271 In Ave
#
#                                   email     Full_Name
# 0                           eu@nibh.com  Joel Padilla
# 1  est.ac.mattis@malesuadafringilla.net   Fritz Tyler
# 2                     dolor@cubilia.net   Wing Phelps
# 3     interdum.libero.dui@vitaeerat.com     Ryan Ross
